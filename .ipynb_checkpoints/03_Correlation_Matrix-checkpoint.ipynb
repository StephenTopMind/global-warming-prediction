# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# STEP 1: Load dataset
df = pd.read_excel("fully_encoded_dataset_complete.xlsx")

# STEP 2: Select only numeric columns
df_numeric = df.select_dtypes(include='number')

# STEP 3: Compute correlation matrix
corr_matrix = df_numeric.corr()

# STEP 4: Plot heatmap
plt.figure(figsize=(18, 14))
sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    annot=False,
    fmt=".2f",
    linewidths=0.5
)
plt.title("Correlation Matrix — Climate Change Survey", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\giuse\AppData\Local\Temp\ipykernel_5112\704344377.py:24: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# STEP 1 — Load dataset
df = pd.read_excel("fully_encoded_dataset_complete.xlsx")

# STEP 2 — Select numeric columns only
df_numeric = df.select_dtypes(include='number')

# STEP 3 — Compute full correlation matrix
corr_matrix = df_numeric.corr()

# STEP 4 — General heatmap
plt.figure(figsize=(18, 14))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix — Climate Survey", fontsize=16)
plt.tight_layout()
plt.show()

# STEP 5 — Top 20 absolute correlations (excluding diagonal)
top_corr = (
    corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    .stack()
    .reset_index()
    .rename(columns={'level_0': 'Variable 1', 'level_1': 'Variable 2', 0: 'Correlation'})
    .assign(AbsCorr=lambda x: x['Correlation'].abs())
    .sort_values(by='AbsCorr', ascending=False)
    .head(20)
)

print("\n Top 20 Correlations:")
print(top_corr)

# STEP 6 — Grouped heatmaps (by thematic blocks)
group_blocks = {
    "Climate Concern": [col for col in df_numeric.columns if "harm" in col.lower() or "worry" in col.lower()],
    "Policy Support": [col for col in df_numeric.columns if "should" in col.lower() or "support" in col.lower()],
    "Personal Behavior": [col for col in df_numeric.columns if "how often" in col.lower()],
    "Political Views": [col for col in df_numeric.columns if "patriotism" in col.lower() or "optimistic" in col.lower() or "politic" in col.lower()]
}

for group_name, cols in group_blocks.items():
    if len(cols) >= 2:
        plt.figure(figsize=(10, 8))
        sns.heatmap(df_numeric[cols].corr(), cmap='coolwarm', annot=True, fmt=".2f", linewidths=0.5)
        plt.title(f"Correlation Matrix — {group_name}", fontsize=14)
        plt.tight_layout()
        plt.show()
# Out:
# C:\Users\giuse\AppData\Local\Temp\ipykernel_5112\2187874780.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
#  Top 20 Correlations:
#                                              Variable 1  \
# 1197  21. The head of state (president, monarch,...)...
# 1237  22. The parliament/assembly/congress legislatu...
# 1198  21. The head of state (president, monarch,...)...
# 1276  23. The governor (of your administrative regio...
# 1238  22. The parliament/assembly/congress legislatu...
# 1156  20. Do you think the following should be doing...
# 1157  20. Do you think the following should be doing...
# 1199  21. The head of state (president, monarch,...)...
# 639   9. How much do you think global warming will h...
# 1314  24. Your local officials (the mayor and the ci...
# 1201  21. The head of state (president, monarch,...)...
# 1240  22. The parliament/assembly/congress legislatu...
# 1277  23. The governor (of your administrative regio...
# 477   6. How much do you think global warming will h...
# 533   7. How much do you think global warming will h...
# 479   6. How much do you think global warming will h...
# 1278  23. The governor (of your administrative regio...
# 1239  22. The parliament/assembly/congress legislatu...
# 1158  20. Do you think the following should be doing...
# 1114  19. Schools should teach our children about th...
#
#                                              Variable 2  Correlation   AbsCorr
# 1197  22. The parliament/assembly/congress legislatu...     0.898366  0.898366
# 1237  23. The governor (of your administrative regio...     0.841437  0.841437
# 1198  23. The governor (of your administrative regio...     0.840548  0.840548
# 1276  24. Your local officials (the mayor and the ci...     0.832409  0.832409
# 1238  24. Your local officials (the mayor and the ci...     0.715927  0.715927
# 1156  21. The head of state (president, monarch,...)...     0.713033  0.713033
# 1157  22. The parliament/assembly/congress legislatu...     0.710877  0.710877
# 1199  24. Your local officials (the mayor and the ci...     0.706724  0.706724
# 639   10. How much do you think global warming will ...     0.702870  0.702870
# 1314                        25. The citizens themselves     0.700038  0.700038
# 1201  26. Should global warming be a priority for th...     0.690256  0.690256
# 1240  26. Should global warming be a priority for th...     0.687783  0.687783
# 1277                        25. The citizens themselves     0.674487  0.674487
# 477   7. How much do you think global warming will h...     0.670661  0.670661
# 533   9. How much do you think global warming will h...     0.653904  0.653904
# 479   9. How much do you think global warming will h...     0.653567  0.653567
# 1278  26. Should global warming be a priority for th...     0.651701  0.651701
# 1239                        25. The citizens themselves     0.651567  0.651567
# 1158  23. The governor (of your administrative regio...     0.650061  0.650061
# 1114  20. Do you think the following should be doing...     0.645073  0.645073
# C:\Users\giuse\AppData\Local\Temp\ipykernel_5112\2187874780.py:49: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# C:\Users\giuse\AppData\Local\Temp\ipykernel_5112\2187874780.py:49: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# C:\Users\giuse\AppData\Local\Temp\ipykernel_5112\2187874780.py:49: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
